# %%
from currio.compiled import get_b_njit
import numpy as np

# %%
current_pts = np.array([[-0.5, 0, 0], [0.5, 0, 0]])
pts = np.array([[0, 0, 1]])
current = np.array([[1e-3]])
get_b_njit(current_pts, pts, current)
# Out:
# array([[[0.00000000e+00]],
#
#        [[8.94427191e-05]],
#
#        [[0.00000000e+00]]])

# %%
current_pts = np.array([[-200., 0, 0], [200., 0, 0]])
pts = np.array([[0, 0, 1]])
current = np.array([[1e-3]])
get_b_njit(current_pts, pts, current)
# Out:
# array([[[0.    ]],
#
#        [[0.0002]],
#
#        [[0.    ]]])
