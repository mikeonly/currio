# %%
from currio.compiled import get_b_njit
import numpy as np

# %%
current_pts = np.array([[-0.5, 0, 0], [0.5, 0, 0]])
pts = np.array([[0, 0, 1]])
current = np.array([[1e-3]])
get_b_njit(current_pts, pts, current)
# Out:
# array([[[0.00000000e+00]],
#
#        [[8.94427191e-05]],
#
#        [[0.00000000e+00]]])

# %% [markdown]
# To understand the units and confirm what they are throughout the code, we can use a known equation in a limiting case. Here, we will use the magnetic field of an infinite straight wire
#
# $$B = \frac{\mu_0 I}{2 \pi r}$$

# %%
current_pts = np.array([[-2000., 0, 0], [2000., 0, 0]])
pts = np.array([[0, 0, 1]])
current = np.array([[1.]])
get_b_njit(current_pts, pts, current)
# Out:
# array([[[0.        ]],
#
#        [[0.19999998]],
#
#        [[0.        ]]])
